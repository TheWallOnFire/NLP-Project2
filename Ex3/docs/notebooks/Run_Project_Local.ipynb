# %% [markdown]
# # Run Banking AI-Agent Locally
#
# This notebook provides the steps to run the FastAPI application and Ollama model entirely on your local machine.

# %% [markdown]
# ### Step 1: Install Ollama
# Ensure you have Ollama installed on your system. If not, download it from [ollama.com](https://ollama.com/).

# %% [markdown]
# ### Step 2: Pull the Model
# Run this cell or open your terminal and run this command to pull the required model:

# %%
# !ollama pull gpt-oss:20b

# %% [markdown]
# ### Step 3: Install Dependencies
# Install the required Python packages for the FastAPI server.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### Step 4: Run the Application
# Start the FastAPI server. The API will be available at `http://localhost:8000`.

# %%
# !python run.py
